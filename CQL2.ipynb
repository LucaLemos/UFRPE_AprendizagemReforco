# %%
from IPython.display import clear_output
import sys
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from util.algorithms import run_sarsa

# %%
# Verifica se está rodando no Google Colab
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    # !git clone https://github.com/LucaLemos/UFRPE_AprendizagemReforco
    sys.path.append("/content/UFRPE_AprendizagemReforco")
    clear_output()
    # !apt-get install ffmpeg
    # !pip install gymnasium==1.0.0
else:
    from os import path
    sys.path.append(path.dirname(path.dirname(path.abspath("__main__"))))

# %%
# Hiperparâmetros Globais
GAMMA = 0.95  # Fator de desconto
TAU = 0.005   # Taxa de atualização da target_network
ALPHA = 0.5   # Peso do termo CQL
ITERATIONS = 5000  # Número de iterações do CQL
DATASET_SIZE = 1_000_000  # Tamanho do conjunto de dados (replay buffer)
BATCH_SIZE = 128  # Tamanho do batch para treinamento da rede neural
LEARNING_RATE = 1e-3  # Taxa de aprendizado para o otimizador
TARGET_UPDATE_FREQ = 200  # Atualizar a target network a cada 200 iterações

# %%
# Definição da Rede Q
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, action_dim)

    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# Função para converter estados em tensores one-hot
def to_one_hot(state, num_states):
    one_hot = np.zeros(num_states)
    one_hot[state] = 1
    return torch.FloatTensor(one_hot)

# %%
# Função para amostrar um batch do replay buffer
def sample_batch(replay_buffer, batch_size, states_dim):
    """Retorna um batch aleatório de transições do buffer."""
    indices = np.random.choice(len(replay_buffer), batch_size, replace=False)
    batch = [replay_buffer[i] for i in indices]

    # Extrai apenas os 5 elementos necessários
    states, actions, rewards, next_states, dones = zip(*[(s, a, r, ns, d) for (s, a, r, ns, _, _, d, _) in batch])

    # Converte para tensores
    states = torch.stack([to_one_hot(s, states_dim) for s in states])
    next_states = torch.stack([to_one_hot(ns, states_dim) for ns in next_states])
    actions = torch.LongTensor(actions).unsqueeze(1)
    rewards = torch.FloatTensor(rewards).unsqueeze(1)
    dones = torch.FloatTensor(dones).unsqueeze(1)

    return states, actions, rewards, next_states, dones

# %%
# Função para calcular a perda CQL
def cql_loss(q_network, states, actions, target_q_values, alpha=0.5):
    q_values = q_network(states).gather(1, actions)
    all_q_values = q_network(states)
    logsumexp_q = torch.logsumexp(all_q_values, dim=1, keepdim=True)
    penalty = logsumexp_q - q_values
    loss = torch.mean((q_values - target_q_values) ** 2) + alpha * torch.mean(penalty)
    return loss

# %%
# Função para treinar o modelo CQL
def train_cql(q_network, target_network, replay_buffer, states_dim, q_values_means, rewards_variances, batch_size=64, optimizer=None, alpha=0.5, gamma=0.95):
    states, actions, rewards, next_states, dones = sample_batch(replay_buffer, batch_size, states_dim)
    q_values = q_network(states).gather(1, actions)
    with torch.no_grad():
        next_q_values = target_network(next_states).max(1, keepdim=True)[0]
        target_q_values = rewards + gamma * next_q_values * (1 - dones)
    loss = cql_loss(q_network, states, actions, target_q_values, alpha)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    q_values_means.append(q_values.mean().item())
    rewards_variances.append(torch.var(rewards).item())
    return loss, q_values_means, rewards_variances

# %%
# Função para avaliar a política
def evaluate_policy(q_network, env, states_dim, num_episodes=100, max_steps=50000):
    total_rewards = []
    for _ in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0
        step = 0
        while not done and step < max_steps:
            state_one_hot = to_one_hot(state, states_dim).unsqueeze(0)
            q_values = q_network(state_one_hot)
            action = torch.argmax(q_values).item()
            state, reward, done, _, _ = env.step(action)
            total_reward += reward
            step += 1
        total_rewards.append(total_reward)
    return np.mean(total_rewards)

# %%
# Função para atualizar a target network
def update_target_network(q_network, target_network, tau=0.005):
    for target_param, param in zip(target_network.parameters(), q_network.parameters()):
        target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

# %%
# Função para treinar e salvar o modelo
def train_and_save_model(env_name, env, replay_buffer, states_dim, actions_dim, batch_size, learning_rate, gamma, alpha, iterations, evaluate_every, target_update_freq, model_save_path):
    q_network = QNetwork(states_dim, actions_dim)
    target_network = QNetwork(states_dim, actions_dim)
    target_network.load_state_dict(q_network.state_dict())
    optimizer = optim.Adam(q_network.parameters(), lr=learning_rate)
    losses = []
    avg_rewards = []
    q_values_means = []
    rewards_variances = []
    for iteration in range(iterations):
        loss, q_values_means, rewards_variances = train_cql(q_network, target_network, replay_buffer, states_dim, q_values_means, rewards_variances, batch_size, optimizer, alpha, gamma)
        if (iteration + 1) % target_update_freq == 0:
            update_target_network(q_network, target_network, TAU)
        if (iteration + 1) % evaluate_every == 0:
            avg_reward = evaluate_policy(q_network, env, states_dim)
            avg_rewards.append(avg_reward)
            losses.append(loss.item())
            print(f"Iteração {iteration + 1}, Perda: {loss.item()}, Recompensa Média: {avg_reward}")
    torch.save(q_network.state_dict(), model_save_path)
    print(f"Modelo salvo em {model_save_path}")
    return q_network, losses, avg_rewards

# %% [markdown]
# # FrozenLake

# %%
# Função específica para FrozenLake
def train_frozenlake():
    env_name = "FrozenLake-v1"
    env = gym.make(env_name, render_mode="rgb_array")
    states_dim = env.observation_space.n
    actions_dim = env.action_space.n
    model_save_path = f"model/q_network_{env_name}.pth"

    # Hiperparâmetros específicos para FrozenLake
    batch_size = 128
    learning_rate = 1e-3
    gamma = 0.95
    alpha = 0.5
    iterations = 5000
    evaluate_every = 1000
    target_update_freq = 200

    # Coleta dados
    sum_rewards_per_ep, _, transitions = run_sarsa(env, DATASET_SIZE, learning_rate, gamma)
    replay_buffer = transitions

    # Treina e salva o modelo
    q_network, losses, avg_rewards = train_and_save_model(
        env_name, env, replay_buffer, states_dim, actions_dim, batch_size, learning_rate,
        gamma, alpha, iterations, evaluate_every, target_update_freq, model_save_path
    )
    print(f"Ambiente: {env_name}")
    print(f"Recompensa média final: {np.mean(avg_rewards)}")
    print(f"Variância da recompensa: {np.var(avg_rewards)}")
    print("-" * 50)

# %%
train_frozenlake()
# Out:
# Run sarsa in <TimeLimit<OrderEnforcing<PassiveEnvChecker<FrozenLakeEnv<FrozenLake-v1>>>>>
# Episódio 0 terminou com recompensa 0.0 na transição 29
# Episódio 100 terminou com recompensa 0.0 na transição 1517
# Episódio 200 terminou com recompensa 0.0 na transição 3253
# Episódio 300 terminou com recompensa 0.0 na transição 4897
# Episódio 400 terminou com recompensa 0.0 na transição 6447
# Episódio 500 terminou com recompensa 0.0 na transição 8067
# Episódio 600 terminou com recompensa 0.0 na transição 9669
# Episódio 700 terminou com recompensa 0.0 na transição 11228
# Episódio 800 terminou com recompensa 0.0 na transição 12742
# Episódio 900 terminou com recompensa 0.0 na transição 14290
# Episódio 1000 terminou com recompensa 0.0 na transição 15726
# Episódio 1100 terminou com recompensa 0.0 na transição 16911
# Episódio 1200 terminou com recompensa 1.0 na transição 18235
# Episódio 1300 terminou com recompensa 0.0 na transição 19509
# Episódio 1400 terminou com recompensa 0.0 na transição 20746
# Episódio 1500 terminou com recompensa 0.0 na transição 22145
# Episódio 1600 terminou com recompensa 0.0 na transição 23399
# Episódio 1700 terminou com recompensa 0.0 na transição 24739
# Episódio 1800 terminou com recompensa 0.0 na transição 26126
# Episódio 1900 terminou com recompensa 0.0 na transição 27507
# Episódio 2000 terminou com recompensa 0.0 na transição 28796
# Episódio 2100 terminou com recompensa 0.0 na transição 30268
# Episódio 2200 terminou com recompensa 0.0 na transição 31633
# Episódio 2300 terminou com recompensa 0.0 na transição 33141
# Episódio 2400 terminou com recompensa 0.0 na transição 34545
# Episódio 2500 terminou com recompensa 0.0 na transição 35875
# Episódio 2600 terminou com recompensa 0.0 na transição 37130
# Episódio 2700 terminou com recompensa 0.0 na transição 38663
# Episódio 2800 terminou com recompensa 0.0 na transição 40074
# Episódio 2900 terminou com recompensa 0.0 na transição 41560
# Episódio 3000 terminou com recompensa 0.0 na transição 42752
# Episódio 3100 terminou com recompensa 0.0 na transição 44101
# Episódio 3200 terminou com recompensa 0.0 na transição 45520
# Episódio 3300 terminou com recompensa 0.0 na transição 46938
# Episódio 3400 terminou com recompensa 0.0 na transição 48148
# Episódio 3500 terminou com recompensa 0.0 na transição 49535
# Episódio 3600 terminou com recompensa 0.0 na transição 51143
# Episódio 3700 terminou com recompensa 0.0 na transição 52400
# Episódio 3800 terminou com recompensa 0.0 na transição 53753
# Episódio 3900 terminou com recompensa 0.0 na transição 55259
# Episódio 4000 terminou com recompensa 0.0 na transição 56638
# Episódio 4100 terminou com recompensa 0.0 na transição 58118
# Episódio 4200 terminou com recompensa 0.0 na transição 59405
# Episódio 4300 terminou com recompensa 0.0 na transição 60797
# Episódio 4400 terminou com recompensa 0.0 na transição 62176
# Episódio 4500 terminou com recompensa 0.0 na transição 63373
# Episódio 4600 terminou com recompensa 0.0 na transição 64821
# Episódio 4700 terminou com recompensa 0.0 na transição 66083
# Episódio 4800 terminou com recompensa 0.0 na transição 67341
# Episódio 4900 terminou com recompensa 0.0 na transição 68589
# Episódio 5000 terminou com recompensa 0.0 na transição 69988
# Episódio 5100 terminou com recompensa 0.0 na transição 71287
# Episódio 5200 terminou com recompensa 0.0 na transição 72632
# Episódio 5300 terminou com recompensa 0.0 na transição 73896
# Episódio 5400 terminou com recompensa 0.0 na transição 75246
# Episódio 5500 terminou com recompensa 0.0 na transição 76622
# Episódio 5600 terminou com recompensa 0.0 na transição 77883
# Episódio 5700 terminou com recompensa 0.0 na transição 79332
# Episódio 5800 terminou com recompensa 0.0 na transição 80785
# Episódio 5900 terminou com recompensa 0.0 na transição 82283
# Episódio 6000 terminou com recompensa 0.0 na transição 83520
# Episódio 6100 terminou com recompensa 0.0 na transição 84855
# Episódio 6200 terminou com recompensa 0.0 na transição 86308
# Episódio 6300 terminou com recompensa 0.0 na transição 87859
# Episódio 6400 terminou com recompensa 0.0 na transição 89207
# Episódio 6500 terminou com recompensa 0.0 na transição 90473
# Episódio 6600 terminou com recompensa 0.0 na transição 91826
# Episódio 6700 terminou com recompensa 0.0 na transição 93337
# Episódio 6800 terminou com recompensa 0.0 na transição 94798
# Episódio 6900 terminou com recompensa 0.0 na transição 96190
# Episódio 7000 terminou com recompensa 0.0 na transição 97562
# Episódio 7100 terminou com recompensa 0.0 na transição 98929
# Episódio 7200 terminou com recompensa 0.0 na transição 100136
# Episódio 7300 terminou com recompensa 0.0 na transição 101535
# Episódio 7400 terminou com recompensa 0.0 na transição 102940
# Episódio 7500 terminou com recompensa 0.0 na transição 104399
# Episódio 7600 terminou com recompensa 0.0 na transição 105639
# Episódio 7700 terminou com recompensa 0.0 na transição 107067
# Episódio 7800 terminou com recompensa 0.0 na transição 108425
# Episódio 7900 terminou com recompensa 1.0 na transição 109748
# Episódio 8000 terminou com recompensa 0.0 na transição 111016
# Episódio 8100 terminou com recompensa 0.0 na transição 112606
# Episódio 8200 terminou com recompensa 0.0 na transição 113903
# Episódio 8300 terminou com recompensa 1.0 na transição 115325
# Episódio 8400 terminou com recompensa 0.0 na transição 116715
# Episódio 8500 terminou com recompensa 0.0 na transição 117948
# Episódio 8600 terminou com recompensa 0.0 na transição 119342
# Episódio 8700 terminou com recompensa 1.0 na transição 120683
# Episódio 8800 terminou com recompensa 0.0 na transição 122157
# Episódio 8900 terminou com recompensa 0.0 na transição 123498
# Episódio 9000 terminou com recompensa 0.0 na transição 124752
# Episódio 9100 terminou com recompensa 0.0 na transição 126271
# Episódio 9200 terminou com recompensa 0.0 na transição 127525
# Episódio 9300 terminou com recompensa 0.0 na transição 128748
# Episódio 9400 terminou com recompensa 0.0 na transição 130129
# Episódio 9500 terminou com recompensa 0.0 na transição 131577
# Episódio 9600 terminou com recompensa 0.0 na transição 132909
# Episódio 9700 terminou com recompensa 0.0 na transição 134084
# Episódio 9800 terminou com recompensa 0.0 na transição 135626
# Episódio 9900 terminou com recompensa 1.0 na transição 137015
# Episódio 10000 terminou com recompensa 0.0 na transição 138477
# Episódio 10100 terminou com recompensa 0.0 na transição 139740
# Episódio 10200 terminou com recompensa 1.0 na transição 141057
# Episódio 10300 terminou com recompensa 0.0 na transição 142445
# Episódio 10400 terminou com recompensa 0.0 na transição 143843
# Episódio 10500 terminou com recompensa 0.0 na transição 145338
# Episódio 10600 terminou com recompensa 0.0 na transição 146619
# Episódio 10700 terminou com recompensa 0.0 na transição 147991
# Episódio 10800 terminou com recompensa 0.0 na transição 149419
# Episódio 10900 terminou com recompensa 0.0 na transição 150918
# Episódio 11000 terminou com recompensa 0.0 na transição 152156
# Episódio 11100 terminou com recompensa 1.0 na transição 153354
# Episódio 11200 terminou com recompensa 0.0 na transição 154752
# Episódio 11300 terminou com recompensa 0.0 na transição 156027
# Episódio 11400 terminou com recompensa 0.0 na transição 157396
# Episódio 11500 terminou com recompensa 0.0 na transição 158819
# Episódio 11600 terminou com recompensa 0.0 na transição 160299
# Episódio 11700 terminou com recompensa 0.0 na transição 161764
# Episódio 11800 terminou com recompensa 0.0 na transição 162953
# Episódio 11900 terminou com recompensa 0.0 na transição 164301
# Episódio 12000 terminou com recompensa 0.0 na transição 165608
# Episódio 12100 terminou com recompensa 0.0 na transição 167028
# Episódio 12200 terminou com recompensa 0.0 na transição 168368
# Episódio 12300 terminou com recompensa 0.0 na transição 169641
# Episódio 12400 terminou com recompensa 0.0 na transição 171129
# Episódio 12500 terminou com recompensa 0.0 na transição 172307
# Episódio 12600 terminou com recompensa 0.0 na transição 173634
# Episódio 12700 terminou com recompensa 0.0 na transição 175078
# Episódio 12800 terminou com recompensa 0.0 na transição 176519
# Episódio 12900 terminou com recompensa 0.0 na transição 177824
# Episódio 13000 terminou com recompensa 0.0 na transição 179265
# Episódio 13100 terminou com recompensa 1.0 na transição 180626
# Episódio 13200 terminou com recompensa 0.0 na transição 181952
# Episódio 13300 terminou com recompensa 0.0 na transição 183448
# Episódio 13400 terminou com recompensa 0.0 na transição 184797
# Episódio 13500 terminou com recompensa 0.0 na transição 186121
# Episódio 13600 terminou com recompensa 0.0 na transição 187388
# Episódio 13700 terminou com recompensa 0.0 na transição 188784
# Episódio 13800 terminou com recompensa 0.0 na transição 189997
# Episódio 13900 terminou com recompensa 0.0 na transição 191481
# Episódio 14000 terminou com recompensa 0.0 na transição 192864
# Episódio 14100 terminou com recompensa 0.0 na transição 194102
# Episódio 14200 terminou com recompensa 0.0 na transição 195523
# Episódio 14300 terminou com recompensa 0.0 na transição 197027
# Episódio 14400 terminou com recompensa 0.0 na transição 198229
# Episódio 14500 terminou com recompensa 0.0 na transição 199539
# Episódio 14600 terminou com recompensa 0.0 na transição 200795
# Episódio 14700 terminou com recompensa 0.0 na transição 202064
# Episódio 14800 terminou com recompensa 0.0 na transição 203324
# Episódio 14900 terminou com recompensa 0.0 na transição 204785
# Episódio 15000 terminou com recompensa 0.0 na transição 206118
# Episódio 15100 terminou com recompensa 0.0 na transição 207623
# Episódio 15200 terminou com recompensa 0.0 na transição 209038
# Episódio 15300 terminou com recompensa 0.0 na transição 210458
# Episódio 15400 terminou com recompensa 0.0 na transição 211931
# Episódio 15500 terminou com recompensa 0.0 na transição 213202
# Episódio 15600 terminou com recompensa 0.0 na transição 214471
# Episódio 15700 terminou com recompensa 0.0 na transição 215895
# Episódio 15800 terminou com recompensa 0.0 na transição 217277
# Episódio 15900 terminou com recompensa 0.0 na transição 218648
# Episódio 16000 terminou com recompensa 0.0 na transição 219865
# Episódio 16100 terminou com recompensa 0.0 na transição 221167
# Episódio 16200 terminou com recompensa 0.0 na transição 222648
# Episódio 16300 terminou com recompensa 0.0 na transição 223898
# Episódio 16400 terminou com recompensa 0.0 na transição 225152
# Episódio 16500 terminou com recompensa 0.0 na transição 226541
# Episódio 16600 terminou com recompensa 0.0 na transição 228091
# Episódio 16700 terminou com recompensa 0.0 na transição 229498
# Episódio 16800 terminou com recompensa 0.0 na transição 230868
# Episódio 16900 terminou com recompensa 0.0 na transição 232312
# Episódio 17000 terminou com recompensa 0.0 na transição 233616
# Episódio 17100 terminou com recompensa 0.0 na transição 234849
# Episódio 17200 terminou com recompensa 0.0 na transição 236385
# Episódio 17300 terminou com recompensa 0.0 na transição 237741
# Episódio 17400 terminou com recompensa 0.0 na transição 239282
# Episódio 17500 terminou com recompensa 0.0 na transição 240573
# Episódio 17600 terminou com recompensa 0.0 na transição 241895
# Episódio 17700 terminou com recompensa 0.0 na transição 243346
# Episódio 17800 terminou com recompensa 0.0 na transição 244681
# Episódio 17900 terminou com recompensa 0.0 na transição 245905
# Episódio 18000 terminou com recompensa 0.0 na transição 247374
# Episódio 18100 terminou com recompensa 0.0 na transição 248907
# Episódio 18200 terminou com recompensa 0.0 na transição 250352
# Episódio 18300 terminou com recompensa 0.0 na transição 251663
# Episódio 18400 terminou com recompensa 0.0 na transição 253308
# Episódio 18500 terminou com recompensa 0.0 na transição 254591
# Episódio 18600 terminou com recompensa 0.0 na transição 256011
# Episódio 18700 terminou com recompensa 0.0 na transição 257556
# Episódio 18800 terminou com recompensa 0.0 na transição 259076
# Episódio 18900 terminou com recompensa 0.0 na transição 260347
# Episódio 19000 terminou com recompensa 0.0 na transição 261752
# Episódio 19100 terminou com recompensa 0.0 na transição 263130
# Episódio 19200 terminou com recompensa 0.0 na transição 264472
# Episódio 19300 terminou com recompensa 0.0 na transição 265735
# Episódio 19400 terminou com recompensa 0.0 na transição 267409
# Episódio 19500 terminou com recompensa 0.0 na transição 268760
# Episódio 19600 terminou com recompensa 0.0 na transição 270066
# Episódio 19700 terminou com recompensa 0.0 na transição 271548
# Episódio 19800 terminou com recompensa 0.0 na transição 272875
# Episódio 19900 terminou com recompensa 0.0 na transição 274178
# Episódio 20000 terminou com recompensa 0.0 na transição 275693
# Episódio 20100 terminou com recompensa 0.0 na transição 277159
# Episódio 20200 terminou com recompensa 0.0 na transição 278428
# Episódio 20300 terminou com recompensa 0.0 na transição 279777
# Episódio 20400 terminou com recompensa 0.0 na transição 281137
# Episódio 20500 terminou com recompensa 0.0 na transição 282509
# Episódio 20600 terminou com recompensa 0.0 na transição 283881
# Episódio 20700 terminou com recompensa 0.0 na transição 285382
# Episódio 20800 terminou com recompensa 0.0 na transição 286834
# Episódio 20900 terminou com recompensa 0.0 na transição 288202
# Episódio 21000 terminou com recompensa 0.0 na transição 289457
# Episódio 21100 terminou com recompensa 0.0 na transição 290670
# Episódio 21200 terminou com recompensa 0.0 na transição 291901
# Episódio 21300 terminou com recompensa 0.0 na transição 293288
# Episódio 21400 terminou com recompensa 0.0 na transição 294660
# Episódio 21500 terminou com recompensa 1.0 na transição 296010
# Episódio 21600 terminou com recompensa 0.0 na transição 297407
# Episódio 21700 terminou com recompensa 0.0 na transição 299026
# Episódio 21800 terminou com recompensa 0.0 na transição 300398
# Episódio 21900 terminou com recompensa 0.0 na transição 301864
# Episódio 22000 terminou com recompensa 0.0 na transição 303171
# Episódio 22100 terminou com recompensa 0.0 na transição 304567
# Episódio 22200 terminou com recompensa 0.0 na transição 305893
# Episódio 22300 terminou com recompensa 0.0 na transição 307356
# Episódio 22400 terminou com recompensa 0.0 na transição 308930
# Episódio 22500 terminou com recompensa 0.0 na transição 310199
# Episódio 22600 terminou com recompensa 0.0 na transição 311386
# Episódio 22700 terminou com recompensa 0.0 na transição 312759
# Episódio 22800 terminou com recompensa 0.0 na transição 314084
# Episódio 22900 terminou com recompensa 0.0 na transição 315413
# Episódio 23000 terminou com recompensa 0.0 na transição 316829
# Episódio 23100 terminou com recompensa 0.0 na transição 318252
# Episódio 23200 terminou com recompensa 0.0 na transição 319572
# Episódio 23300 terminou com recompensa 0.0 na transição 320964
# Episódio 23400 terminou com recompensa 0.0 na transição 322473
# Episódio 23500 terminou com recompensa 0.0 na transição 323614
# Episódio 23600 terminou com recompensa 0.0 na transição 324952
# Episódio 23700 terminou com recompensa 0.0 na transição 326069
# Episódio 23800 terminou com recompensa 0.0 na transição 327454
# Episódio 23900 terminou com recompensa 0.0 na transição 328781
# Episódio 24000 terminou com recompensa 0.0 na transição 330137
# Episódio 24100 terminou com recompensa 0.0 na transição 331420
# Episódio 24200 terminou com recompensa 0.0 na transição 332705
# Episódio 24300 terminou com recompensa 0.0 na transição 333988
# Episódio 24400 terminou com recompensa 0.0 na transição 335368
# Episódio 24500 terminou com recompensa 0.0 na transição 336795
# Episódio 24600 terminou com recompensa 0.0 na transição 338317
# Episódio 24700 terminou com recompensa 0.0 na transição 339491
# Episódio 24800 terminou com recompensa 0.0 na transição 340819
# Episódio 24900 terminou com recompensa 0.0 na transição 342313
# Episódio 25000 terminou com recompensa 0.0 na transição 343803
# Episódio 25100 terminou com recompensa 0.0 na transição 345086
# Episódio 25200 terminou com recompensa 1.0 na transição 346413
# Episódio 25300 terminou com recompensa 1.0 na transição 347826
# Episódio 25400 terminou com recompensa 0.0 na transição 349529
# Episódio 25500 terminou com recompensa 0.0 na transição 351280
# Episódio 25600 terminou com recompensa 0.0 na transição 352619
# Episódio 25700 terminou com recompensa 0.0 na transição 354071
# Episódio 25800 terminou com recompensa 0.0 na transição 355382
# Episódio 25900 terminou com recompensa 0.0 na transição 356792
# Episódio 26000 terminou com recompensa 1.0 na transição 358083
# Episódio 26100 terminou com recompensa 0.0 na transição 359259
# Episódio 26200 terminou com recompensa 0.0 na transição 360463
# Episódio 26300 terminou com recompensa 0.0 na transição 361882
# Episódio 26400 terminou com recompensa 0.0 na transição 363006
# Episódio 26500 terminou com recompensa 0.0 na transição 364354
# Episódio 26600 terminou com recompensa 0.0 na transição 365592
# Episódio 26700 terminou com recompensa 0.0 na transição 366887
# Episódio 26800 terminou com recompensa 0.0 na transição 368231
# Episódio 26900 terminou com recompensa 0.0 na transição 369432
# Episódio 27000 terminou com recompensa 0.0 na transição 370810
# Episódio 27100 terminou com recompensa 0.0 na transição 372116
# Episódio 27200 terminou com recompensa 0.0 na transição 373502
# Episódio 27300 terminou com recompensa 0.0 na transição 374793
# Episódio 27400 terminou com recompensa 0.0 na transição 376165
# Episódio 27500 terminou com recompensa 1.0 na transição 377508
# Episódio 27600 terminou com recompensa 0.0 na transição 378988
# Episódio 27700 terminou com recompensa 0.0 na transição 380366
# Episódio 27800 terminou com recompensa 0.0 na transição 381592
# Episódio 27900 terminou com recompensa 0.0 na transição 382961
# Episódio 28000 terminou com recompensa 0.0 na transição 384270
# Episódio 28100 terminou com recompensa 0.0 na transição 385431
# Episódio 28200 terminou com recompensa 0.0 na transição 386890
# Episódio 28300 terminou com recompensa 0.0 na transição 388116
# Episódio 28400 terminou com recompensa 0.0 na transição 389523
# Episódio 28500 terminou com recompensa 0.0 na transição 390936
# Episódio 28600 terminou com recompensa 0.0 na transição 392363
# Episódio 28700 terminou com recompensa 0.0 na transição 393710
# Episódio 28800 terminou com recompensa 0.0 na transição 395017
# Episódio 28900 terminou com recompensa 0.0 na transição 396450
# Episódio 29000 terminou com recompensa 1.0 na transição 397803
# Episódio 29100 terminou com recompensa 0.0 na transição 399324
# Episódio 29200 terminou com recompensa 0.0 na transição 400745
# Episódio 29300 terminou com recompensa 0.0 na transição 401919
# Episódio 29400 terminou com recompensa 0.0 na transição 403202
# Episódio 29500 terminou com recompensa 0.0 na transição 404607
# Episódio 29600 terminou com recompensa 0.0 na transição 405874
# Episódio 29700 terminou com recompensa 0.0 na transição 407416
# Episódio 29800 terminou com recompensa 0.0 na transição 408671
# Episódio 29900 terminou com recompensa 0.0 na transição 410005
# Episódio 30000 terminou com recompensa 0.0 na transição 411438
# Episódio 30100 terminou com recompensa 0.0 na transição 412933
# Episódio 30200 terminou com recompensa 0.0 na transição 414237
# Episódio 30300 terminou com recompensa 0.0 na transição 415524
# Episódio 30400 terminou com recompensa 0.0 na transição 416954
# Episódio 30500 terminou com recompensa 0.0 na transição 418092
# Episódio 30600 terminou com recompensa 0.0 na transição 419425
# Episódio 30700 terminou com recompensa 0.0 na transição 420701
# Episódio 30800 terminou com recompensa 0.0 na transição 422187
# Episódio 30900 terminou com recompensa 0.0 na transição 423550
# Episódio 31000 terminou com recompensa 0.0 na transição 424994
# Episódio 31100 terminou com recompensa 0.0 na transição 426394
# Episódio 31200 terminou com recompensa 0.0 na transição 427722
# Episódio 31300 terminou com recompensa 0.0 na transição 428916
# Episódio 31400 terminou com recompensa 0.0 na transição 430262
# Episódio 31500 terminou com recompensa 0.0 na transição 431652
# Episódio 31600 terminou com recompensa 0.0 na transição 433054
# Episódio 31700 terminou com recompensa 0.0 na transição 434597
# Episódio 31800 terminou com recompensa 1.0 na transição 435851
# Episódio 31900 terminou com recompensa 0.0 na transição 437106
# Episódio 32000 terminou com recompensa 0.0 na transição 438490
# Episódio 32100 terminou com recompensa 0.0 na transição 439837
# Episódio 32200 terminou com recompensa 0.0 na transição 441385
# Episódio 32300 terminou com recompensa 0.0 na transição 442621
# Episódio 32400 terminou com recompensa 0.0 na transição 443815
# Episódio 32500 terminou com recompensa 0.0 na transição 445281
# Episódio 32600 terminou com recompensa 0.0 na transição 446414
# Episódio 32700 terminou com recompensa 0.0 na transição 447645
# Episódio 32800 terminou com recompensa 0.0 na transição 448975
# Episódio 32900 terminou com recompensa 0.0 na transição 450425
# Episódio 33000 terminou com recompensa 0.0 na transição 451801
# Episódio 33100 terminou com recompensa 0.0 na transição 453063
# Episódio 33200 terminou com recompensa 0.0 na transição 454605
# Episódio 33300 terminou com recompensa 0.0 na transição 455954
# Episódio 33400 terminou com recompensa 0.0 na transição 457301
# Episódio 33500 terminou com recompensa 0.0 na transição 458643
# Episódio 33600 terminou com recompensa 0.0 na transição 459905
# Episódio 33700 terminou com recompensa 0.0 na transição 461415
# Episódio 33800 terminou com recompensa 0.0 na transição 462765
# Episódio 33900 terminou com recompensa 0.0 na transição 464131
# Episódio 34000 terminou com recompensa 0.0 na transição 465401
# Episódio 34100 terminou com recompensa 0.0 na transição 466682
# Episódio 34200 terminou com recompensa 0.0 na transição 468224
# Episódio 34300 terminou com recompensa 0.0 na transição 469484
# Episódio 34400 terminou com recompensa 0.0 na transição 470916
# Episódio 34500 terminou com recompensa 0.0 na transição 472471
# Episódio 34600 terminou com recompensa 0.0 na transição 473645
# Episódio 34700 terminou com recompensa 1.0 na transição 475095
# Episódio 34800 terminou com recompensa 0.0 na transição 476491
# Episódio 34900 terminou com recompensa 0.0 na transição 477963
# Episódio 35000 terminou com recompensa 1.0 na transição 479252
# Episódio 35100 terminou com recompensa 0.0 na transição 480483
# Episódio 35200 terminou com recompensa 0.0 na transição 481959
# Episódio 35300 terminou com recompensa 0.0 na transição 483082
# Episódio 35400 terminou com recompensa 0.0 na transição 484704
# Episódio 35500 terminou com recompensa 0.0 na transição 486046
# Episódio 35600 terminou com recompensa 0.0 na transição 487386
# Episódio 35700 terminou com recompensa 0.0 na transição 488684
# Episódio 35800 terminou com recompensa 0.0 na transição 489980
# Episódio 35900 terminou com recompensa 0.0 na transição 491230
# Episódio 36000 terminou com recompensa 0.0 na transição 492613
# Episódio 36100 terminou com recompensa 0.0 na transição 493988
# Episódio 36200 terminou com recompensa 0.0 na transição 495166
# Episódio 36300 terminou com recompensa 0.0 na transição 496598
# Episódio 36400 terminou com recompensa 0.0 na transição 498068
# Episódio 36500 terminou com recompensa 0.0 na transição 499462
# Episódio 36600 terminou com recompensa 0.0 na transição 500695
# Episódio 36700 terminou com recompensa 0.0 na transição 501962
# Episódio 36800 terminou com recompensa 0.0 na transição 503382
# Episódio 36900 terminou com recompensa 0.0 na transição 504880
# Episódio 37000 terminou com recompensa 0.0 na transição 506224
# Episódio 37100 terminou com recompensa 0.0 na transição 507478
# Episódio 37200 terminou com recompensa 0.0 na transição 508739
# Episódio 37300 terminou com recompensa 0.0 na transição 510106
# Episódio 37400 terminou com recompensa 0.0 na transição 511436
# Episódio 37500 terminou com recompensa 0.0 na transição 512899
# Episódio 37600 terminou com recompensa 0.0 na transição 514385
# Episódio 37700 terminou com recompensa 0.0 na transição 516003
# Episódio 37800 terminou com recompensa 0.0 na transição 517446
# Episódio 37900 terminou com recompensa 0.0 na transição 518743
# Episódio 38000 terminou com recompensa 0.0 na transição 520203
# Episódio 38100 terminou com recompensa 1.0 na transição 521641
# Episódio 38200 terminou com recompensa 0.0 na transição 523024
# Episódio 38300 terminou com recompensa 0.0 na transição 524619
# Episódio 38400 terminou com recompensa 0.0 na transição 526073
# Episódio 38500 terminou com recompensa 0.0 na transição 527506
# Episódio 38600 terminou com recompensa 0.0 na transição 528895
# Episódio 38700 terminou com recompensa 0.0 na transição 530313
# Episódio 38800 terminou com recompensa 0.0 na transição 531744
# Episódio 38900 terminou com recompensa 0.0 na transição 532999
# Episódio 39000 terminou com recompensa 0.0 na transição 534548
# Episódio 39100 terminou com recompensa 0.0 na transição 536061
# Episódio 39200 terminou com recompensa 0.0 na transição 537406
# Episódio 39300 terminou com recompensa 0.0 na transição 538716
# Episódio 39400 terminou com recompensa 0.0 na transição 540108
# Episódio 39500 terminou com recompensa 0.0 na transição 541406
# Episódio 39600 terminou com recompensa 0.0 na transição 542687
# Episódio 39700 terminou com recompensa 0.0 na transição 544143
# Episódio 39800 terminou com recompensa 0.0 na transição 545575
# Episódio 39900 terminou com recompensa 0.0 na transição 546945
# Episódio 40000 terminou com recompensa 0.0 na transição 548404
# Episódio 40100 terminou com recompensa 0.0 na transição 549885
# Episódio 40200 terminou com recompensa 0.0 na transição 551309
# Episódio 40300 terminou com recompensa 0.0 na transição 552733
# Episódio 40400 terminou com recompensa 0.0 na transição 554267
# Episódio 40500 terminou com recompensa 0.0 na transição 555610
# Episódio 40600 terminou com recompensa 0.0 na transição 556975
# Episódio 40700 terminou com recompensa 0.0 na transição 558399
# Episódio 40800 terminou com recompensa 0.0 na transição 559869
# Episódio 40900 terminou com recompensa 0.0 na transição 561114
# Episódio 41000 terminou com recompensa 0.0 na transição 562551
# Episódio 41100 terminou com recompensa 1.0 na transição 563831
# Episódio 41200 terminou com recompensa 0.0 na transição 565133
# Episódio 41300 terminou com recompensa 0.0 na transição 566598
# Episódio 41400 terminou com recompensa 0.0 na transição 567887
# Episódio 41500 terminou com recompensa 0.0 na transição 569350
# Episódio 41600 terminou com recompensa 0.0 na transição 570666
# Episódio 41700 terminou com recompensa 0.0 na transição 572217
# Episódio 41800 terminou com recompensa 0.0 na transição 573666
# Episódio 41900 terminou com recompensa 0.0 na transição 575141
# Episódio 42000 terminou com recompensa 0.0 na transição 576210
# Episódio 42100 terminou com recompensa 0.0 na transição 577825
# Episódio 42200 terminou com recompensa 0.0 na transição 579262
# Episódio 42300 terminou com recompensa 0.0 na transição 580584
# Episódio 42400 terminou com recompensa 0.0 na transição 581984
# Episódio 42500 terminou com recompensa 0.0 na transição 583352
# Episódio 42600 terminou com recompensa 0.0 na transição 584842
# Episódio 42700 terminou com recompensa 0.0 na transição 586286
# Episódio 42800 terminou com recompensa 0.0 na transição 587765
# Episódio 42900 terminou com recompensa 0.0 na transição 588955
# Episódio 43000 terminou com recompensa 0.0 na transição 590311
# Episódio 43100 terminou com recompensa 0.0 na transição 591800
# Episódio 43200 terminou com recompensa 0.0 na transição 593092
# Episódio 43300 terminou com recompensa 0.0 na transição 594431
# Episódio 43400 terminou com recompensa 0.0 na transição 595766
# Episódio 43500 terminou com recompensa 0.0 na transição 597313
# Episódio 43600 terminou com recompensa 0.0 na transição 598779
# Episódio 43700 terminou com recompensa 0.0 na transição 600056
# Episódio 43800 terminou com recompensa 0.0 na transição 601475
# Episódio 43900 terminou com recompensa 0.0 na transição 602854
# Episódio 44000 terminou com recompensa 0.0 na transição 604449
# Episódio 44100 terminou com recompensa 0.0 na transição 605764
# Episódio 44200 terminou com recompensa 0.0 na transição 607063
# Episódio 44300 terminou com recompensa 0.0 na transição 608553
# Episódio 44400 terminou com recompensa 0.0 na transição 610019
# Episódio 44500 terminou com recompensa 0.0 na transição 611642
# Episódio 44600 terminou com recompensa 0.0 na transição 612988
# Episódio 44700 terminou com recompensa 0.0 na transição 614392
# Episódio 44800 terminou com recompensa 0.0 na transição 615671
# Episódio 44900 terminou com recompensa 0.0 na transição 617055
# Episódio 45000 terminou com recompensa 1.0 na transição 618387
# Episódio 45100 terminou com recompensa 0.0 na transição 619657
# Episódio 45200 terminou com recompensa 0.0 na transição 621137
# Episódio 45300 terminou com recompensa 0.0 na transição 622631
# Episódio 45400 terminou com recompensa 0.0 na transição 624090
# Episódio 45500 terminou com recompensa 0.0 na transição 625497
# Episódio 45600 terminou com recompensa 0.0 na transição 626840
# Episódio 45700 terminou com recompensa 0.0 na transição 628210
# Episódio 45800 terminou com recompensa 0.0 na transição 629553
# Episódio 45900 terminou com recompensa 0.0 na transição 631011
# Episódio 46000 terminou com recompensa 0.0 na transição 632586
# Episódio 46100 terminou com recompensa 0.0 na transição 634070
# Episódio 46200 terminou com recompensa 0.0 na transição 635419
# Episódio 46300 terminou com recompensa 0.0 na transição 636886
# Episódio 46400 terminou com recompensa 0.0 na transição 638332
# Episódio 46500 terminou com recompensa 0.0 na transição 639588
# Episódio 46600 terminou com recompensa 0.0 na transição 640908
# Episódio 46700 terminou com recompensa 1.0 na transição 642247
# Episódio 46800 terminou com recompensa 1.0 na transição 643652
# Episódio 46900 terminou com recompensa 0.0 na transição 645064
# Episódio 47000 terminou com recompensa 0.0 na transição 646628
# Episódio 47100 terminou com recompensa 0.0 na transição 648056
# Episódio 47200 terminou com recompensa 0.0 na transição 649498
# Episódio 47300 terminou com recompensa 0.0 na transição 650710
# Episódio 47400 terminou com recompensa 0.0 na transição 652024
# Episódio 47500 terminou com recompensa 0.0 na transição 653441
# Episódio 47600 terminou com recompensa 0.0 na transição 654822
# Episódio 47700 terminou com recompensa 0.0 na transição 656266
# Episódio 47800 terminou com recompensa 0.0 na transição 657584
# Episódio 47900 terminou com recompensa 0.0 na transição 658887
# Episódio 48000 terminou com recompensa 0.0 na transição 660345
# Episódio 48100 terminou com recompensa 0.0 na transição 661839
# Episódio 48200 terminou com recompensa 0.0 na transição 663287
# Episódio 48300 terminou com recompensa 0.0 na transição 664520
# Episódio 48400 terminou com recompensa 0.0 na transição 665994
# Episódio 48500 terminou com recompensa 0.0 na transição 667289
# Episódio 48600 terminou com recompensa 0.0 na transição 668699
# Episódio 48700 terminou com recompensa 0.0 na transição 670130
# Episódio 48800 terminou com recompensa 0.0 na transição 671355
# Episódio 48900 terminou com recompensa 0.0 na transição 672563
# Episódio 49000 terminou com recompensa 0.0 na transição 674116
# Episódio 49100 terminou com recompensa 0.0 na transição 675293
# Episódio 49200 terminou com recompensa 0.0 na transição 676806
# Episódio 49300 terminou com recompensa 1.0 na transição 678190
# Episódio 49400 terminou com recompensa 0.0 na transição 679555
# Episódio 49500 terminou com recompensa 0.0 na transição 680761
# Episódio 49600 terminou com recompensa 0.0 na transição 682116
# Episódio 49700 terminou com recompensa 0.0 na transição 683502
# Episódio 49800 terminou com recompensa 0.0 na transição 684957
# Episódio 49900 terminou com recompensa 0.0 na transição 686523
# Episódio 50000 terminou com recompensa 0.0 na transição 687951
# Episódio 50100 terminou com recompensa 0.0 na transição 689400
# Episódio 50200 terminou com recompensa 0.0 na transição 690729
# Episódio 50300 terminou com recompensa 0.0 na transição 692147
# Episódio 50400 terminou com recompensa 0.0 na transição 693665
# Episódio 50500 terminou com recompensa 0.0 na transição 695035
# Episódio 50600 terminou com recompensa 0.0 na transição 696641
# Episódio 50700 terminou com recompensa 0.0 na transição 698009
# Episódio 50800 terminou com recompensa 0.0 na transição 699301
# Episódio 50900 terminou com recompensa 1.0 na transição 700867
# Episódio 51000 terminou com recompensa 0.0 na transição 702240
# Episódio 51100 terminou com recompensa 0.0 na transição 703713
# Episódio 51200 terminou com recompensa 1.0 na transição 705171
# Episódio 51300 terminou com recompensa 0.0 na transição 706364
# Episódio 51400 terminou com recompensa 0.0 na transição 707631
# Episódio 51500 terminou com recompensa 0.0 na transição 708975
# Episódio 51600 terminou com recompensa 0.0 na transição 710208
# Episódio 51700 terminou com recompensa 0.0 na transição 711667
# Episódio 51800 terminou com recompensa 0.0 na transição 712959
# Episódio 51900 terminou com recompensa 0.0 na transição 714323
# Episódio 52000 terminou com recompensa 0.0 na transição 715561
# Episódio 52100 terminou com recompensa 0.0 na transição 716835
# Episódio 52200 terminou com recompensa 0.0 na transição 718297
# Episódio 52300 terminou com recompensa 0.0 na transição 719573
# Episódio 52400 terminou com recompensa 0.0 na transição 721077
# Episódio 52500 terminou com recompensa 0.0 na transição 722434
# Episódio 52600 terminou com recompensa 0.0 na transição 723784
# Episódio 52700 terminou com recompensa 0.0 na transição 725211
# Episódio 52800 terminou com recompensa 0.0 na transição 726427
# Episódio 52900 terminou com recompensa 0.0 na transição 727776
# Episódio 53000 terminou com recompensa 0.0 na transição 729092
# Episódio 53100 terminou com recompensa 0.0 na transição 730439
# Episódio 53200 terminou com recompensa 0.0 na transição 731929
# Episódio 53300 terminou com recompensa 0.0 na transição 733390
# Episódio 53400 terminou com recompensa 0.0 na transição 734919
# Episódio 53500 terminou com recompensa 0.0 na transição 736322
# Episódio 53600 terminou com recompensa 0.0 na transição 737556
# Episódio 53700 terminou com recompensa 0.0 na transição 738829
# Episódio 53800 terminou com recompensa 0.0 na transição 740316
# Episódio 53900 terminou com recompensa 0.0 na transição 741795
# Episódio 54000 terminou com recompensa 0.0 na transição 743102
# Episódio 54100 terminou com recompensa 0.0 na transição 744491
# Episódio 54200 terminou com recompensa 0.0 na transição 745890
# Episódio 54300 terminou com recompensa 0.0 na transição 747260
# Episódio 54400 terminou com recompensa 0.0 na transição 748721
# Episódio 54500 terminou com recompensa 0.0 na transição 749989
# Episódio 54600 terminou com recompensa 0.0 na transição 751144
# Episódio 54700 terminou com recompensa 0.0 na transição 752550
# Episódio 54800 terminou com recompensa 0.0 na transição 753770
# Episódio 54900 terminou com recompensa 0.0 na transição 755078
# Episódio 55000 terminou com recompensa 0.0 na transição 756485
# Episódio 55100 terminou com recompensa 0.0 na transição 757985
# Episódio 55200 terminou com recompensa 0.0 na transição 759437
# Episódio 55300 terminou com recompensa 0.0 na transição 760752
# Episódio 55400 terminou com recompensa 0.0 na transição 761962
# Episódio 55500 terminou com recompensa 0.0 na transição 763366
# Episódio 55600 terminou com recompensa 0.0 na transição 764666
# Episódio 55700 terminou com recompensa 0.0 na transição 765986
# Episódio 55800 terminou com recompensa 0.0 na transição 767334
# Episódio 55900 terminou com recompensa 0.0 na transição 768655
# Episódio 56000 terminou com recompensa 0.0 na transição 770193
# Episódio 56100 terminou com recompensa 0.0 na transição 771528
# Episódio 56200 terminou com recompensa 0.0 na transição 772828
# Episódio 56300 terminou com recompensa 0.0 na transição 774243
# Episódio 56400 terminou com recompensa 0.0 na transição 775769
# Episódio 56500 terminou com recompensa 0.0 na transição 777175
# Episódio 56600 terminou com recompensa 0.0 na transição 778440
# Episódio 56700 terminou com recompensa 0.0 na transição 779654
# Episódio 56800 terminou com recompensa 0.0 na transição 780885
# Episódio 56900 terminou com recompensa 0.0 na transição 782242
# Episódio 57000 terminou com recompensa 0.0 na transição 783738
# Episódio 57100 terminou com recompensa 0.0 na transição 785064
# Episódio 57200 terminou com recompensa 0.0 na transição 786270
# Episódio 57300 terminou com recompensa 0.0 na transição 787820
# Episódio 57400 terminou com recompensa 0.0 na transição 788937
# Episódio 57500 terminou com recompensa 0.0 na transição 790484
# Episódio 57600 terminou com recompensa 0.0 na transição 791943
# Episódio 57700 terminou com recompensa 0.0 na transição 793382
# Episódio 57800 terminou com recompensa 0.0 na transição 794818
# Episódio 57900 terminou com recompensa 0.0 na transição 796317
# Episódio 58000 terminou com recompensa 0.0 na transição 797866
# Episódio 58100 terminou com recompensa 0.0 na transição 799260
# Episódio 58200 terminou com recompensa 0.0 na transição 800429
# Episódio 58300 terminou com recompensa 0.0 na transição 801800
# Episódio 58400 terminou com recompensa 0.0 na transição 802996
# Episódio 58500 terminou com recompensa 0.0 na transição 804339
# Episódio 58600 terminou com recompensa 0.0 na transição 805902
# Episódio 58700 terminou com recompensa 0.0 na transição 807080
# Episódio 58800 terminou com recompensa 0.0 na transição 808418
# Episódio 58900 terminou com recompensa 0.0 na transição 809636
# Episódio 59000 terminou com recompensa 1.0 na transição 810774
# Episódio 59100 terminou com recompensa 0.0 na transição 812109
# Episódio 59200 terminou com recompensa 1.0 na transição 813658
# Episódio 59300 terminou com recompensa 0.0 na transição 815010
# Episódio 59400 terminou com recompensa 1.0 na transição 816430
# Episódio 59500 terminou com recompensa 0.0 na transição 817718
# Episódio 59600 terminou com recompensa 0.0 na transição 818949
# Episódio 59700 terminou com recompensa 0.0 na transição 820282
# Episódio 59800 terminou com recompensa 0.0 na transição 821694
# Episódio 59900 terminou com recompensa 0.0 na transição 822902
# Episódio 60000 terminou com recompensa 0.0 na transição 824209
# Episódio 60100 terminou com recompensa 0.0 na transição 825508
# Episódio 60200 terminou com recompensa 0.0 na transição 826732
# Episódio 60300 terminou com recompensa 0.0 na transição 827896
# Episódio 60400 terminou com recompensa 0.0 na transição 829233
# Episódio 60500 terminou com recompensa 0.0 na transição 830802
# Episódio 60600 terminou com recompensa 0.0 na transição 832252
# Episódio 60700 terminou com recompensa 0.0 na transição 833623
# Episódio 60800 terminou com recompensa 1.0 na transição 835054
# Episódio 60900 terminou com recompensa 0.0 na transição 836405
# Episódio 61000 terminou com recompensa 0.0 na transição 837675
# Episódio 61100 terminou com recompensa 0.0 na transição 838950
# Episódio 61200 terminou com recompensa 0.0 na transição 840336
# Episódio 61300 terminou com recompensa 0.0 na transição 841750
# Episódio 61400 terminou com recompensa 0.0 na transição 842923
# Episódio 61500 terminou com recompensa 0.0 na transição 844338
# Episódio 61600 terminou com recompensa 0.0 na transição 846090
# Episódio 61700 terminou com recompensa 0.0 na transição 848243
# Episódio 61800 terminou com recompensa 0.0 na transição 849957
# Episódio 61900 terminou com recompensa 0.0 na transição 852304
# Episódio 62000 terminou com recompensa 0.0 na transição 854553
# Episódio 62100 terminou com recompensa 0.0 na transição 856277
# Episódio 62200 terminou com recompensa 0.0 na transição 858178
# Episódio 62300 terminou com recompensa 0.0 na transição 860123
# Episódio 62400 terminou com recompensa 0.0 na transição 862125
# Episódio 62500 terminou com recompensa 0.0 na transição 864012
# Episódio 62600 terminou com recompensa 0.0 na transição 866077
# Episódio 62700 terminou com recompensa 0.0 na transição 868039
# Episódio 62800 terminou com recompensa 0.0 na transição 869906
# Episódio 62900 terminou com recompensa 1.0 na transição 871978
# Episódio 63000 terminou com recompensa 0.0 na transição 873912
# Episódio 63100 terminou com recompensa 0.0 na transição 875914
# Episódio 63200 terminou com recompensa 0.0 na transição 877785
# Episódio 63300 terminou com recompensa 0.0 na transição 879568
# Episódio 63400 terminou com recompensa 0.0 na transição 881869
# Episódio 63500 terminou com recompensa 0.0 na transição 883795
# Episódio 63600 terminou com recompensa 0.0 na transição 885602
# Episódio 63700 terminou com recompensa 0.0 na transição 887544
# Episódio 63800 terminou com recompensa 0.0 na transição 889338
# Episódio 63900 terminou com recompensa 0.0 na transição 891388
# Episódio 64000 terminou com recompensa 0.0 na transição 893403
# Episódio 64100 terminou com recompensa 0.0 na transição 895199
# Episódio 64200 terminou com recompensa 0.0 na transição 897032
# Episódio 64300 terminou com recompensa 1.0 na transição 898931
# Episódio 64400 terminou com recompensa 0.0 na transição 900822
# Episódio 64500 terminou com recompensa 0.0 na transição 902726
# Episódio 64600 terminou com recompensa 0.0 na transição 904469
# Episódio 64700 terminou com recompensa 0.0 na transição 906323
# Episódio 64800 terminou com recompensa 0.0 na transição 908193
# Episódio 64900 terminou com recompensa 0.0 na transição 910185
# Episódio 65000 terminou com recompensa 0.0 na transição 912196
# Episódio 65100 terminou com recompensa 0.0 na transição 914242
# Episódio 65200 terminou com recompensa 1.0 na transição 916514
# Episódio 65300 terminou com recompensa 0.0 na transição 918663
# Episódio 65400 terminou com recompensa 1.0 na transição 920658
# Episódio 65500 terminou com recompensa 0.0 na transição 922670
# Episódio 65600 terminou com recompensa 1.0 na transição 924802
# Episódio 65700 terminou com recompensa 0.0 na transição 926678
# Episódio 65800 terminou com recompensa 0.0 na transição 928655
# Episódio 65900 terminou com recompensa 0.0 na transição 930688
# Episódio 66000 terminou com recompensa 0.0 na transição 932575
# Episódio 66100 terminou com recompensa 1.0 na transição 934575
# Episódio 66200 terminou com recompensa 0.0 na transição 936798
# Episódio 66300 terminou com recompensa 1.0 na transição 938654
# Episódio 66400 terminou com recompensa 0.0 na transição 941062
# Episódio 66500 terminou com recompensa 0.0 na transição 942824
# Episódio 66600 terminou com recompensa 0.0 na transição 944617
# Episódio 66700 terminou com recompensa 1.0 na transição 946341
# Episódio 66800 terminou com recompensa 0.0 na transição 948150
# Episódio 66900 terminou com recompensa 0.0 na transição 950083
# Episódio 67000 terminou com recompensa 0.0 na transição 952084
# Episódio 67100 terminou com recompensa 0.0 na transição 954176
# Episódio 67200 terminou com recompensa 0.0 na transição 956209
# Episódio 67300 terminou com recompensa 0.0 na transição 957968
# Episódio 67400 terminou com recompensa 0.0 na transição 960407
# Episódio 67500 terminou com recompensa 0.0 na transição 962461
# Episódio 67600 terminou com recompensa 0.0 na transição 964481
# Episódio 67700 terminou com recompensa 0.0 na transição 966663
# Episódio 67800 terminou com recompensa 0.0 na transição 968457
# Episódio 67900 terminou com recompensa 1.0 na transição 970371
# Episódio 68000 terminou com recompensa 0.0 na transição 972370
# Episódio 68100 terminou com recompensa 0.0 na transição 974128
# Episódio 68200 terminou com recompensa 0.0 na transição 975965
# Episódio 68300 terminou com recompensa 0.0 na transição 978124
# Episódio 68400 terminou com recompensa 0.0 na transição 980241
# Episódio 68500 terminou com recompensa 0.0 na transição 982274
# Episódio 68600 terminou com recompensa 0.0 na transição 984096
# Episódio 68700 terminou com recompensa 0.0 na transição 986305
# Episódio 68800 terminou com recompensa 0.0 na transição 988278
# Episódio 68900 terminou com recompensa 0.0 na transição 990120
# Episódio 69000 terminou com recompensa 0.0 na transição 992223
# Episódio 69100 terminou com recompensa 0.0 na transição 993933
# Episódio 69200 terminou com recompensa 0.0 na transição 995648
# Episódio 69300 terminou com recompensa 0.0 na transição 997626
# Episódio 69400 terminou com recompensa 0.0 na transição 999633
# Iteração 1000, Perda: 0.4781818985939026, Recompensa Média: 0.06
# Iteração 2000, Perda: 0.46712082624435425, Recompensa Média: 0.1
# Iteração 3000, Perda: 0.5028008818626404, Recompensa Média: 0.08
# Iteração 4000, Perda: 0.5205259323120117, Recompensa Média: 0.05
# Iteração 5000, Perda: 0.37233859300613403, Recompensa Média: 0.08
# Modelo salvo em model/q_network_FrozenLake-v1.pth
# Ambiente: FrozenLake-v1
# Recompensa média final: 0.074
# Variância da recompensa: 0.00030400000000000007
# --------------------------------------------------

# %% [markdown]
# # Taxi

# %%
# Função específica para Taxi
def train_taxi():
    env_name = "Taxi-v3"
    env = gym.make(env_name, render_mode="rgb_array")
    states_dim = env.observation_space.n
    actions_dim = env.action_space.n
    model_save_path = f"model/q_network_{env_name}.pth"

    # Hiperparâmetros específicos para Taxi
    batch_size = 256
    learning_rate = 1e-4  # Taxa de aprendizado menor
    gamma = 0.99  # Fator de desconto maior
    alpha = 0.2
    iterations = 5000  # Número maior de iterações
    evaluate_every = 1000
    target_update_freq = 500

    # Coleta dados
    sum_rewards_per_ep, _, transitions = run_sarsa(env, DATASET_SIZE, learning_rate, gamma)
    replay_buffer = transitions

    # Treina e salva o modelo
    q_network, losses, avg_rewards = train_and_save_model(
        env_name, env, replay_buffer, states_dim, actions_dim, batch_size, learning_rate,
        gamma, alpha, iterations, evaluate_every, target_update_freq, model_save_path
    )
    print(f"Ambiente: {env_name}")
    print(f"Recompensa média final: {np.mean(avg_rewards)}")
    print(f"Variância da recompensa: {np.var(avg_rewards)}")
    print("-" * 50)

# %%
train_taxi()
# Out:
# Run sarsa in <TimeLimit<OrderEnforcing<PassiveEnvChecker<TaxiEnv<Taxi-v3>>>>>
# Episódio 0 terminou com recompensa -686 na transição 199
# Episódio 100 terminou com recompensa -254 na transição 18943
# Episódio 200 terminou com recompensa -317 na transição 37871
# Episódio 300 terminou com recompensa -299 na transição 56789
# Episódio 400 terminou com recompensa -245 na transição 75934
# Episódio 500 terminou com recompensa -254 na transição 94625
# Episódio 600 terminou com recompensa -254 na transição 113681
# Episódio 700 terminou com recompensa -272 na transição 133049
# Episódio 800 terminou com recompensa -41 na transição 152134
# Episódio 900 terminou com recompensa -308 na transição 171298
# Episódio 1000 terminou com recompensa -389 na transição 190587
# Episódio 1100 terminou com recompensa -272 na transição 209553
# Episódio 1200 terminou com recompensa -245 na transição 228628
# Episódio 1300 terminou com recompensa -263 na transição 247836
# Episódio 1400 terminou com recompensa -204 na transição 266702
# Episódio 1500 terminou com recompensa -317 na transição 285848
# Episódio 1600 terminou com recompensa -281 na transição 305238
# Episódio 1700 terminou com recompensa -254 na transição 324300
# Episódio 1800 terminou com recompensa -272 na transição 343593
# Episódio 1900 terminou com recompensa -245 na transição 362267
# Episódio 2000 terminou com recompensa -326 na transição 381413
# Episódio 2100 terminou com recompensa -380 na transição 400324
# Episódio 2200 terminou com recompensa -299 na transição 419242
# Episódio 2300 terminou com recompensa -308 na transição 438204
# Episódio 2400 terminou com recompensa -272 na transição 457313
# Episódio 2500 terminou com recompensa -99 na transição 476463
# Episódio 2600 terminou com recompensa -263 na transição 495631
# Episódio 2700 terminou com recompensa -290 na transição 514731
# Episódio 2800 terminou com recompensa -168 na transição 533815
# Episódio 2900 terminou com recompensa -245 na transição 552853
# Episódio 3000 terminou com recompensa -290 na transição 571721
# Episódio 3100 terminou com recompensa -281 na transição 589937
# Episódio 3200 terminou com recompensa -254 na transição 609369
# Episódio 3300 terminou com recompensa -263 na transição 627900
# Episódio 3400 terminou com recompensa -317 na transição 646963
# Episódio 3500 terminou com recompensa -263 na transição 666089
# Episódio 3600 terminou com recompensa -254 na transição 685482
# Episódio 3700 terminou com recompensa -290 na transição 704450
# Episódio 3800 terminou com recompensa -290 na transição 723579
# Episódio 3900 terminou com recompensa -272 na transição 742801
# Episódio 4000 terminou com recompensa -245 na transição 761558
# Episódio 4100 terminou com recompensa -130 na transição 780357
# Episódio 4200 terminou com recompensa -240 na transição 799505
# Episódio 4300 terminou com recompensa -272 na transição 818139
# Episódio 4400 terminou com recompensa -263 na transição 837264
# Episódio 4500 terminou com recompensa -308 na transição 856250
# Episódio 4600 terminou com recompensa -245 na transição 875240
# Episódio 4700 terminou com recompensa -317 na transição 894282
# Episódio 4800 terminou com recompensa -290 na transição 912977
# Episódio 4900 terminou com recompensa -308 na transição 931963
# Episódio 5000 terminou com recompensa -245 na transição 951031
# Episódio 5100 terminou com recompensa -353 na transição 970089
# Episódio 5200 terminou com recompensa -335 na transição 989114
# Iteração 1000, Perda: 0.7027384042739868, Recompensa Média: -50000.0
# Iteração 2000, Perda: 2.5711896419525146, Recompensa Média: -50000.0
# Iteração 3000, Perda: 0.39297541975975037, Recompensa Média: -50000.0
# Iteração 4000, Perda: 0.6253024935722351, Recompensa Média: -50000.0
# Iteração 5000, Perda: 0.6581645011901855, Recompensa Média: -50000.0
# Modelo salvo em model/q_network_Taxi-v3.pth
# Ambiente: Taxi-v3
# Recompensa média final: -50000.0
# Variância da recompensa: 0.0
# --------------------------------------------------

# %% [markdown]
# # Cliff

# %%
# Função específica para CliffWalking
def train_cliffwalking():
    env_name = "CliffWalking-v0"
    env = gym.make(env_name, render_mode="rgb_array")
    states_dim = env.observation_space.n
    actions_dim = env.action_space.n
    model_save_path = f"model/q_network_{env_name}.pth"

    # Hiperparâmetros específicos para CliffWalking
    batch_size = 64
    learning_rate = 1e-3
    gamma = 0.9
    alpha = 0.1
    iterations = 3000
    evaluate_every = 500
    target_update_freq = 100

    # Coleta dados
    sum_rewards_per_ep, _, transitions = run_sarsa(env, DATASET_SIZE, learning_rate, gamma)
    replay_buffer = transitions

    # Treina e salva o modelo
    q_network, losses, avg_rewards = train_and_save_model(
        env_name, env, replay_buffer, states_dim, actions_dim, batch_size, learning_rate,
        gamma, alpha, iterations, evaluate_every, target_update_freq, model_save_path
    )
    print(f"Ambiente: {env_name}")
    print(f"Recompensa média final: {np.mean(avg_rewards)}")
    print(f"Variância da recompensa: {np.var(avg_rewards)}")
    print("-" * 50)

# %%
train_cliffwalking()
# Out:
# Run sarsa in <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v0>>>>
# Episódio 0 terminou com recompensa -213 na transição 113
# Episódio 100 terminou com recompensa -1492 na transição 50534
# Episódio 200 terminou com recompensa -1271 na transição 86760
# Episódio 300 terminou com recompensa -130 na transição 115744
# Episódio 400 terminou com recompensa -84 na transição 140906
# Episódio 500 terminou com recompensa -143 na transição 165407
# Episódio 600 terminou com recompensa -399 na transição 187304
# Episódio 700 terminou com recompensa -547 na transição 207077
# Episódio 800 terminou com recompensa -122 na transição 225002
# Episódio 900 terminou com recompensa -392 na transição 240924
# Episódio 1000 terminou com recompensa -296 na transição 257766
# Episódio 1100 terminou com recompensa -74 na transição 272250
# Episódio 1200 terminou com recompensa -65 na transição 287210
# Episódio 1300 terminou com recompensa -45 na transição 300215
# Episódio 1400 terminou com recompensa -177 na transição 314501
# Episódio 1500 terminou com recompensa -188 na transição 325954
# Episódio 1600 terminou com recompensa -92 na transição 337915
# Episódio 1700 terminou com recompensa -69 na transição 350121
# Episódio 1800 terminou com recompensa -234 na transição 360824
# Episódio 1900 terminou com recompensa -102 na transição 370366
# Episódio 2000 terminou com recompensa -80 na transição 381587
# Episódio 2100 terminou com recompensa -57 na transição 392278
# Episódio 2200 terminou com recompensa -247 na transição 402582
# Episódio 2300 terminou com recompensa -161 na transição 412167
# Episódio 2400 terminou com recompensa -103 na transição 421249
# Episódio 2500 terminou com recompensa -57 na transição 430264
# Episódio 2600 terminou com recompensa -41 na transição 438916
# Episódio 2700 terminou com recompensa -193 na transição 448503
# Episódio 2800 terminou com recompensa -80 na transição 457184
# Episódio 2900 terminou com recompensa -70 na transição 466624
# Episódio 3000 terminou com recompensa -214 na transição 475105
# Episódio 3100 terminou com recompensa -191 na transição 482324
# Episódio 3200 terminou com recompensa -100 na transição 489976
# Episódio 3300 terminou com recompensa -103 na transição 497828
# Episódio 3400 terminou com recompensa -80 na transição 505330
# Episódio 3500 terminou com recompensa -38 na transição 512947
# Episódio 3600 terminou com recompensa -74 na transição 520347
# Episódio 3700 terminou com recompensa -194 na transição 527287
# Episódio 3800 terminou com recompensa -59 na transição 534834
# Episódio 3900 terminou com recompensa -91 na transição 541627
# Episódio 4000 terminou com recompensa -343 na transição 548662
# Episódio 4100 terminou com recompensa -38 na transição 555627
# Episódio 4200 terminou com recompensa -40 na transição 561899
# Episódio 4300 terminou com recompensa -84 na transição 568486
# Episódio 4400 terminou com recompensa -57 na transição 575496
# Episódio 4500 terminou com recompensa -54 na transição 582454
# Episódio 4600 terminou com recompensa -52 na transição 589037
# Episódio 4700 terminou com recompensa -37 na transição 595993
# Episódio 4800 terminou com recompensa -70 na transição 602901
# Episódio 4900 terminou com recompensa -68 na transição 609063
# Episódio 5000 terminou com recompensa -31 na transição 615342
# Episódio 5100 terminou com recompensa -175 na transição 620515
# Episódio 5200 terminou com recompensa -187 na transição 625905
# Episódio 5300 terminou com recompensa -292 na transição 631896
# Episódio 5400 terminou com recompensa -53 na transição 637333
# Episódio 5500 terminou com recompensa -24 na transição 642483
# Episódio 5600 terminou com recompensa -49 na transição 647962
# Episódio 5700 terminou com recompensa -27 na transição 653633
# Episódio 5800 terminou com recompensa -61 na transição 659378
# Episódio 5900 terminou com recompensa -39 na transição 665217
# Episódio 6000 terminou com recompensa -41 na transição 670323
# Episódio 6100 terminou com recompensa -163 na transição 675277
# Episódio 6200 terminou com recompensa -43 na transição 680088
# Episódio 6300 terminou com recompensa -131 na transição 685213
# Episódio 6400 terminou com recompensa -47 na transição 690594
# Episódio 6500 terminou com recompensa -135 na transição 695238
# Episódio 6600 terminou com recompensa -47 na transição 700179
# Episódio 6700 terminou com recompensa -52 na transição 705085
# Episódio 6800 terminou com recompensa -35 na transição 709620
# Episódio 6900 terminou com recompensa -46 na transição 714423
# Episódio 7000 terminou com recompensa -53 na transição 720028
# Episódio 7100 terminou com recompensa -69 na transição 725015
# Episódio 7200 terminou com recompensa -49 na transição 730164
# Episódio 7300 terminou com recompensa -38 na transição 734798
# Episódio 7400 terminou com recompensa -57 na transição 739441
# Episódio 7500 terminou com recompensa -166 na transição 744051
# Episódio 7600 terminou com recompensa -53 na transição 748279
# Episódio 7700 terminou com recompensa -79 na transição 753160
# Episódio 7800 terminou com recompensa -37 na transição 757546
# Episódio 7900 terminou com recompensa -47 na transição 761968
# Episódio 8000 terminou com recompensa -37 na transição 766152
# Episódio 8100 terminou com recompensa -37 na transição 770609
# Episódio 8200 terminou com recompensa -38 na transição 775514
# Episódio 8300 terminou com recompensa -34 na transição 780141
# Episódio 8400 terminou com recompensa -55 na transição 784302
# Episódio 8500 terminou com recompensa -45 na transição 788524
# Episódio 8600 terminou com recompensa -47 na transição 792308
# Episódio 8700 terminou com recompensa -28 na transição 796151
# Episódio 8800 terminou com recompensa -38 na transição 800043
# Episódio 8900 terminou com recompensa -31 na transição 804168
# Episódio 9000 terminou com recompensa -39 na transição 808136
# Episódio 9100 terminou com recompensa -37 na transição 811882
# Episódio 9200 terminou com recompensa -30 na transição 815941
# Episódio 9300 terminou com recompensa -49 na transição 819757
# Episódio 9400 terminou com recompensa -34 na transição 823466
# Episódio 9500 terminou com recompensa -55 na transição 827337
# Episódio 9600 terminou com recompensa -35 na transição 831594
# Episódio 9700 terminou com recompensa -38 na transição 835396
# Episódio 9800 terminou com recompensa -41 na transição 839100
# Episódio 9900 terminou com recompensa -40 na transição 842807
# Episódio 10000 terminou com recompensa -36 na transição 846474
# Episódio 10100 terminou com recompensa -17 na transição 850186
# Episódio 10200 terminou com recompensa -22 na transição 853832
# Episódio 10300 terminou com recompensa -48 na transição 857638
# Episódio 10400 terminou com recompensa -25 na transição 861170
# Episódio 10500 terminou com recompensa -29 na transição 864850
# Episódio 10600 terminou com recompensa -163 na transição 868650
# Episódio 10700 terminou com recompensa -37 na transição 872365
# Episódio 10800 terminou com recompensa -25 na transição 876309
# Episódio 10900 terminou com recompensa -21 na transição 879646
# Episódio 11000 terminou com recompensa -46 na transição 883540
# Episódio 11100 terminou com recompensa -22 na transição 887222
# Episódio 11200 terminou com recompensa -163 na transição 890565
# Episódio 11300 terminou com recompensa -17 na transição 894013
# Episódio 11400 terminou com recompensa -47 na transição 897543
# Episódio 11500 terminou com recompensa -140 na transição 901142
# Episódio 11600 terminou com recompensa -27 na transição 904485
# Episódio 11700 terminou com recompensa -36 na transição 908088
# Episódio 11800 terminou com recompensa -18 na transição 911492
# Episódio 11900 terminou com recompensa -25 na transição 914496
# Episódio 12000 terminou com recompensa -160 na transição 917652
# Episódio 12100 terminou com recompensa -28 na transição 920876
# Episódio 12200 terminou com recompensa -31 na transição 924282
# Episódio 12300 terminou com recompensa -39 na transição 927730
# Episódio 12400 terminou com recompensa -29 na transição 931039
# Episódio 12500 terminou com recompensa -44 na transição 933886
# Episódio 12600 terminou com recompensa -147 na transição 937089
# Episódio 12700 terminou com recompensa -26 na transição 940116
# Episódio 12800 terminou com recompensa -23 na transição 943355
# Episódio 12900 terminou com recompensa -30 na transição 946785
# Episódio 13000 terminou com recompensa -41 na transição 950232
# Episódio 13100 terminou com recompensa -25 na transição 953305
# Episódio 13200 terminou com recompensa -27 na transição 956238
# Episódio 13300 terminou com recompensa -24 na transição 959170
# Episódio 13400 terminou com recompensa -30 na transição 962167
# Episódio 13500 terminou com recompensa -35 na transição 965341
# Episódio 13600 terminou com recompensa -143 na transição 968258
# Episódio 13700 terminou com recompensa -27 na transição 971158
# Episódio 13800 terminou com recompensa -41 na transição 974225
# Episódio 13900 terminou com recompensa -125 na transição 977242
# Episódio 14000 terminou com recompensa -32 na transição 980257
# Episódio 14100 terminou com recompensa -29 na transição 983297
# Episódio 14200 terminou com recompensa -42 na transição 986531
# Episódio 14300 terminou com recompensa -21 na transição 989475
# Episódio 14400 terminou com recompensa -142 na transição 992306
# Episódio 14500 terminou com recompensa -31 na transição 995092
# Episódio 14600 terminou com recompensa -26 na transição 997816
# Iteração 500, Perda: 0.16160665452480316, Recompensa Média: -50000.0
# Iteração 1000, Perda: 0.15375091135501862, Recompensa Média: -50000.0
# Iteração 1500, Perda: 0.17020608484745026, Recompensa Média: -50000.0
# Iteração 2000, Perda: 0.1441211849451065, Recompensa Média: -50000.0
# Iteração 2500, Perda: 0.1369665265083313, Recompensa Média: -50000.0
# Iteração 3000, Perda: 0.13844527304172516, Recompensa Média: -50000.0
# Modelo salvo em model/q_network_CliffWalking-v0.pth
# Ambiente: CliffWalking-v0
# Recompensa média final: -50000.0
# Variância da recompensa: 0.0
# --------------------------------------------------
